# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Data loading

# %%
df = pd.read_csv("C:/Users/tarun/Downloads/Employee Attrition.csv")
df
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0          1.0                0.38             0.53             2.0
# 1          2.0                0.80             0.86             5.0
# 2          3.0                0.11             0.88             7.0
# 3          4.0                0.72             0.87             5.0
# 4          5.0                0.37             0.52             2.0
# ...        ...                 ...              ...             ...
# 15782  14995.0                0.40             0.57             2.0
# 15783  14996.0                0.37             0.48             2.0
# 15784  14997.0                0.37             0.53             2.0
# 15785  14998.0                0.11             0.96             6.0
# 15786  14999.0                0.37             0.52             2.0
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 0                     157.0                 3.0            0.0
# ...

# %%
df.drop(columns  = ["dept"],inplace=True)

# %%
df.drop(columns  = ["salary"],inplace=True)

# %%
df.drop(columns  = ["Emp ID"],inplace=True)

# %%
# Data info gathering
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15787 entries, 0 to 15786
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  float64
#  3   average_montly_hours   14999 non-null  float64
#  4   time_spend_company     14999 non-null  float64
#  5   Work_accident          14999 non-null  float64
#  6   promotion_last_5years  14999 non-null  float64
# dtypes: float64(7)
# memory usage: 863.5 KB

# %%
# Shape 
df.shape
# Out:
# (15787, 7)

# %%
# Minimum
df.min()
# Out:
# satisfaction_level        0.09
# last_evaluation           0.36
# number_project            2.00
# average_montly_hours     96.00
# time_spend_company        2.00
# Work_accident             0.00
# promotion_last_5years     0.00
# dtype: float64

# %%
# Maximum
df.max()
# Out:
# satisfaction_level         1.0
# last_evaluation            1.0
# number_project             7.0
# average_montly_hours     310.0
# time_spend_company        10.0
# Work_accident              1.0
# promotion_last_5years      1.0
# dtype: float64

# %%
# Count
df.count()
# Out:
# satisfaction_level       14999
# last_evaluation          14999
# number_project           14999
# average_montly_hours     14999
# time_spend_company       14999
# Work_accident            14999
# promotion_last_5years    14999
# dtype: int64

# %%
# Describe
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident  \
# count          14999.000000        14999.000000   14999.000000
# mean             201.050337            3.498233       0.144610
# std               49.943099            1.460136       0.351719
# min               96.000000            2.000000       0.000000
# 25%              156.000000            3.000000       0.000000
# ...

# %%
# Mean
df.mean()
# Out:
# satisfaction_level         0.612834
# last_evaluation            0.716102
# number_project             3.803054
# average_montly_hours     201.050337
# time_spend_company         3.498233
# Work_accident              0.144610
# promotion_last_5years      0.021268
# dtype: float64

# %%
# Median
df.median()
# Out:
# satisfaction_level         0.64
# last_evaluation            0.72
# number_project             4.00
# average_montly_hours     200.00
# time_spend_company         3.00
# Work_accident              0.00
# promotion_last_5years      0.00
# dtype: float64

# %%
# STD
df.std()
# Out:
# satisfaction_level        0.248631
# last_evaluation           0.171169
# number_project            1.232592
# average_montly_hours     49.943099
# time_spend_company        1.460136
# Work_accident             0.351719
# promotion_last_5years     0.144281
# dtype: float64

# %%
# Head
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53             2.0                 157.0
# 1                0.80             0.86             5.0                 262.0
# 2                0.11             0.88             7.0                 272.0
# 3                0.72             0.87             5.0                 223.0
# 4                0.37             0.52             2.0                 159.0
#
#    time_spend_company  Work_accident  promotion_last_5years
# 0                 3.0            0.0                    0.0
# 1                 6.0            0.0                    0.0
# 2                 4.0            0.0                    0.0
# 3                 5.0            0.0                    0.0
# 4                 3.0            0.0                    0.0

# %%
# Tail
df.tail()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 15782                0.40             0.57             2.0
# 15783                0.37             0.48             2.0
# 15784                0.37             0.53             2.0
# 15785                0.11             0.96             6.0
# 15786                0.37             0.52             2.0
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 15782                 151.0                 3.0            0.0
# 15783                 160.0                 3.0            0.0
# 15784                 143.0                 3.0            0.0
# 15785                 280.0                 4.0            0.0
# 15786                 158.0                 3.0            0.0
#
#        promotion_last_5years
# 15782                    0.0
# 15783                    0.0
# 15784                    0.0
# 15785                    0.0
# 15786                    0.0

# %% [markdown]
# # Data Cleaning

# %%
# Missing values
df.isnull()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                   False            False           False
# 1                   False            False           False
# 2                   False            False           False
# 3                   False            False           False
# 4                   False            False           False
# ...                   ...              ...             ...
# 15782               False            False           False
# 15783               False            False           False
# 15784               False            False           False
# 15785               False            False           False
# 15786               False            False           False
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 0                     False               False          False
# 1                     False               False          False
# 2                     False               False          False
# ...

# %%
# Rename
df.rename(columns= {'satisfaction_level':'ALPHA'}, inplace=True)
df
# Out:
#        ALPHA  last_evaluation  number_project  average_montly_hours  \
# 0       0.38             0.53             2.0                 157.0
# 1       0.80             0.86             5.0                 262.0
# 2       0.11             0.88             7.0                 272.0
# 3       0.72             0.87             5.0                 223.0
# 4       0.37             0.52             2.0                 159.0
# ...      ...              ...             ...                   ...
# 15782   0.40             0.57             2.0                 151.0
# 15783   0.37             0.48             2.0                 160.0
# 15784   0.37             0.53             2.0                 143.0
# 15785   0.11             0.96             6.0                 280.0
# 15786   0.37             0.52             2.0                 158.0
#
#        time_spend_company  Work_accident  promotion_last_5years
# 0                     3.0            0.0                    0.0
# ...

# %%
df.drop(columns  = ["Work_accident"],inplace=True)

# %%
df.drop(columns = ["promotion_last_5years"])
# Out:
#        ALPHA  last_evaluation  number_project  average_montly_hours  \
# 0       0.38             0.53             2.0                 157.0
# 1       0.80             0.86             5.0                 262.0
# 2       0.11             0.88             7.0                 272.0
# 3       0.72             0.87             5.0                 223.0
# 4       0.37             0.52             2.0                 159.0
# ...      ...              ...             ...                   ...
# 15782   0.40             0.57             2.0                 151.0
# 15783   0.37             0.48             2.0                 160.0
# 15784   0.37             0.53             2.0                 143.0
# 15785   0.11             0.96             6.0                 280.0
# 15786   0.37             0.52             2.0                 158.0
#
#        time_spend_company
# 0                     3.0
# 1                     6.0
# 2                     4.0
# 3                     5.0
# ...

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 15782     True
# 15783     True
# 15784     True
# 15785     True
# 15786     True
# Length: 15787, dtype: bool

# %% [markdown]
# # Outlier detection

# %%
# Scatter plot
sns.scatterplot(x = 'ALPHA', y = 'last_evaluation', data = df)
# Out:
# <Axes: xlabel='ALPHA', ylabel='last_evaluation'>

# %%
sns.scatterplot(x = 'ALPHA', y = 'number_project', data = df)
# Out:
# <Axes: xlabel='ALPHA', ylabel='number_project'>

# %%
sns.scatterplot(x = 'ALPHA', y = 'average_montly_hours', data = df)
# Out:
# <Axes: xlabel='ALPHA', ylabel='average_montly_hours'>

# %%
sns.scatterplot(x = 'ALPHA', y = 'time_spend_company', data = df)
# Out:
# <Axes: xlabel='ALPHA', ylabel='time_spend_company'>

# %%
sns.scatterplot(x = 'last_evaluation', y = 'ALPHA', data = df)
# Out:
# <Axes: xlabel='last_evaluation', ylabel='ALPHA'>

# %%
sns.scatterplot(x = 'last_evaluation', y = 'number_project', data = df)
# Out:
# <Axes: xlabel='last_evaluation', ylabel='number_project'>

# %%
sns.scatterplot(x = 'last_evaluation', y = 'average_montly_hours', data = df)
# Out:
# <Axes: xlabel='last_evaluation', ylabel='average_montly_hours'>

# %%
sns.scatterplot(x = 'last_evaluation', y = 'time_spend_company', data = df)
# Out:
# <Axes: xlabel='last_evaluation', ylabel='time_spend_company'>

# %%
sns.scatterplot(x = 'number_project', y = 'ALPHA', data = df)
# Out:
# <Axes: xlabel='number_project', ylabel='ALPHA'>

# %%
sns.boxplot(y = 'ALPHA',color = 'g',data = df)
# Out:
# <Axes: ylabel='ALPHA'>

# %%
sns.boxplot(y = 'last_evaluation',color = 'b',data = df)
# Out:
# <Axes: ylabel='last_evaluation'>

# %%
sns.boxplot(y = 'number_project',color = 'y',data = df)
# Out:
# <Axes: ylabel='number_project'>

# %%
sns.boxplot(y = 'time_spend_company',color = 'r',data = df)
# Out:
# <Axes: ylabel='time_spend_company'>

# %%
sns.boxplot(y = 'average_montly_hours', color = 'r', data = df)
# Out:
# <Axes: ylabel='average_montly_hours'>

# %%
sns.regplot(x = 'ALPHA', y = 'last_evaluation', data = df)
# Out:
# <Axes: xlabel='ALPHA', ylabel='last_evaluation'>
